# %% [markdown]
# <a href="https://colab.research.google.com/github/KarnamVishalAI/100day-AI-journey/blob/main/Day01_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#this is just me testing multiple codes dont mind
list = ["berry", "strawberry", "raspberry"]
list[1]= "cherry"
list[:2] =["curry","huppas"]
list.insert(1, "chintu babai")
list.append('chipkali')
list2 = ['Tom', 'Jerry', 'cat']
list.extend(list2)
list.remove("curry")
list.pop(2)
list.pop()
del list[0]
del list
print(list)
# Out:
# <class 'list'>

# %%
list = ["berry", "strawberry", "raspberry"]
list.sort(reverse=True)
list2 = [100,250,12,77,1,144]
list2.sort(reverse=True)
print(list)
print(list2)
# Out:
# ['strawberry', 'raspberry', 'berry']
# [250, 144, 100, 77, 12, 1]

# %%
list = ["berry", "strawberry", "raspberry"]
list.reverse()
print(list)
# Out:
# ['raspberry', 'strawberry', 'berry']

# %%
#hey all this is code where it starts to get hard, here we are using abs to get absolute diff between n and 50.
def myfunc(n):
  return abs(n - 50)

thislist = [100, 50, 65, 82, 23]
thislist.sort(key = myfunc)
print(thislist)
# Out:
# [50, 65, 23, 82, 100]

# %%
#now lets play with loops in lists hehe.....
list = ['what', 'why', 'how']
for x in list:
  print(x)
# Out:
# what
# why
# how

# %%
list = ['what', 'why', 'how']
for i in range(len(list)):
  print(list[i])
# Out:
# what
# why
# how

# %%
# this is simple code for finding sum of list elements, max element in list
list = [1,2,3,4,5]
mylist = sum(list)
maxlist = max(list)
print(mylist, maxlist)
# Out:
# 15 5
